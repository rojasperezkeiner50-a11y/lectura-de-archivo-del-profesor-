# %% [markdown]
# ![true (2).png](data:image/png;base64,...)

# %% [markdown]
# # Lectura de diferentes tipos de archivos desde GitHub
#
# En este notebook se muestran ejemplos de cómo **leer distintos tipos de archivos** almacenados en un repositorio de GitHub utilizando **Python y pandas**.
#
# Los tipos de archivos que veremos son:
# - CSV
# - TXT delimitado
# - JSON
# - Archivos de Excel (`.xlsx`) - con diferentes hojas.
# - Archivos Parquet (`.parquet`)
#
# Para que los ejemplos funcionen con tus propios datos, solo necesitas reemplazar las URL de ejemplo por los **enlaces `raw`** (crudos) de tus archivos en GitHub.

# %% [markdown]
# ## 1. Preparación del entorno
#
# Importamos las librerías necesarias. Principalmente usaremos `pandas`. Para Parquet es recomendable tener instalados `pyarrow` o `fastparquet`.

# %%
import pandas as pd

# Opcional: mostrar más filas/columnas al imprimir dataframes
pd.set_option("display.max_rows", 5)
pd.set_option("display.max_columns", 10)

# %% [markdown]
# ## 2. ¿Cómo obtener la URL `raw` de un archivo en GitHub?
#
# 1. Abre el archivo en GitHub.
# 2. Haz clic en el botón **Raw** (o "Bruto").
# 3. Copia la URL que aparece en el navegador. Esa será la URL que usaremos en `pandas`.
#
# En los ejemplos siguientes se usan URL públicas conocidas o se dejan como **plantilla** para que las reemplaces por tus propios enlaces.

# %% [markdown]
# ## 3. Lectura de archivos CSV desde GitHub
#
# Los archivos CSV son uno de los formatos más comunes para almacenar datos tabulares.
#
# Usaremos una URL de ejemplo del repositorio público `seaborn-data`. Puedes reemplazarla por la tuya.

# %%
# URL de ejemplo de un CSV público en GitHub (dataset 'tips' de seaborn)
#csv_url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"

# Leemos el archivo CSV directamente desde la URL
#df_csv = pd.read_csv(csv_url)
df_csv = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# Mostramos las primeras filas para verificar
df_csv.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 4. Lectura de archivos TXT delimitados desde GitHub
#
# ---
#
#
#
# Cuando el archivo usa otro delimitador distinto a la coma (por ejemplo tabulación `\t` o punto y coma `;`), se puede indicar el separador con el parámetro `sep`.

# %%
# EJEMPLO 2: archivo separado por punto y coma
# Reemplaza esta URL por la de tu archivo TXT en GitHub

txt_url = "https://raw.githubusercontent.com/hmedrano1979/ITC/refs/heads/main/fichero_lab_unir.txt"

df_txt = pd.read_csv(txt_url, sep=",")
df_txt.head()
# Out:
#    Unnamed: 0 num_expediente       fecha      hora  \
# 0           0    2021S000047  01/01/2021  11:38:00
# 1           1    2021S000142  04/01/2021  11:30:00
# 2           2    2021S000142  04/01/2021  11:30:00
# 3           3    2021S000142  04/01/2021  11:30:00
# 4           4    2021S000142  04/01/2021  11:30:00
#
#                                         localizacion  ... coordenada_y_utm  \
# 0  CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...  ...    4.473.586.644
# 1   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  ...    4.476.216.426
# 2   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  ...    4.476.216.426
# 3   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  ...    4.476.216.426
# 4   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  ...    4.476.216.426
#
#    positiva_alcohol positiva_droga tipo_vehiculo lesividad
# 0                 N            NaN           NaN       NaN
# 1                 N            NaN           NaN       NaN
# 2                 N            NaN           NaN       NaN
# 3                 N            NaN           NaN       NaN
# 4                 N            NaN           NaN       NaN
#
# [5 rows x 22 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['cod_distrito'].plot(kind='hist', bins=20, title='cod_distrito')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['cod_lesividad'].plot(kind='hist', bins=20, title='cod_lesividad')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('num_expediente').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('fecha').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('hora').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('localizacion').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Unnamed: 0', y='cod_distrito', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='cod_distrito', y='cod_lesividad', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['cod_lesividad']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('num_expediente')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='num_expediente', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('cod_lesividad')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['cod_lesividad']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('fecha')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='fecha', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('cod_lesividad')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['cod_lesividad']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('hora')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='hora', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('cod_lesividad')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['cod_lesividad']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('localizacion')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='localizacion', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('cod_lesividad')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['cod_distrito'].plot(kind='line', figsize=(8, 4), title='cod_distrito')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['cod_lesividad'].plot(kind='line', figsize=(8, 4), title='cod_lesividad')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['fecha'].value_counts()
#     for x_label, grp in _df_16.groupby('num_expediente')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('num_expediente')
# _ = plt.ylabel('fecha')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['hora'].value_counts()
#     for x_label, grp in _df_17.groupby('fecha')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('fecha')
# _ = plt.ylabel('hora')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['localizacion'].value_counts()
#     for x_label, grp in _df_18.groupby('hora')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('hora')
# _ = plt.ylabel('localizacion')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['numero'].value_counts()
#     for x_label, grp in _df_19.groupby('localizacion')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('localizacion')
# _ = plt.ylabel('numero')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['num_expediente'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='Unnamed: 0', y='num_expediente', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['fecha'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='Unnamed: 0', y='fecha', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_22['hora'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_22, x='Unnamed: 0', y='hora', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['localizacion'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='Unnamed: 0', y='localizacion', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ## 5. Lectura de archivos JSON desde GitHub
#
# Los archivos JSON se utilizan para representar datos estructurados. `pandas` permite leerlos fácilmente con `read_json`.
#
# A continuación se muestra un ejemplo con un JSON público. Si tu JSON tiene otro formato (por ejemplo, una lista de objetos) puede que necesites ajustar el parámetro `orient`.

# %%
# URL de ejemplo de un JSON público (películas de vega-datasets)
json_url = "https://raw.githubusercontent.com/vega/vega-datasets/master/data/movies.json"

# Leemos el archivo JSON
df_json = pd.read_json(json_url)

df_json.head()
# Out:
#                         Title   US Gross  Worldwide Gross  US DVD Sales  \
# 0              The Land Girls   146083.0         146083.0           NaN
# 1      First Love, Last Rites    10876.0          10876.0           NaN
# 2  I Married a Strange Person   203134.0         203134.0           NaN
# 3        Let's Talk About Sex   373615.0         373615.0           NaN
# 4                        Slam  1009819.0        1087521.0           NaN
#
#    Production Budget  ...         Creative Type Director  \
# 0          8000000.0  ...                  None     None
# 1           300000.0  ...                  None     None
# 2           250000.0  ...                  None     None
# 3           300000.0  ...                  None     None
# 4          1000000.0  ...  Contemporary Fiction     None
#
#    Rotten Tomatoes Rating IMDB Rating IMDB Votes
# 0                     NaN         6.1     1071.0
# 1                     NaN         6.9      207.0
# 2                     NaN         6.8      865.0
# 3                    13.0         NaN        NaN
# 4                    62.0         3.4      165.0
#
# [5 rows x 16 columns]

# %% [markdown]
# ### 5.1. JSON línea a línea (NDJSON)
#
# Algunos archivos JSON tienen **una estructura por línea** (también llamado NDJSON o JSON Lines). En ese caso se usa `lines=True`.

# %%
# Plantilla para leer un JSON línea a línea (NDJSON)
json_url = "https://raw.githubusercontent.com/hmedrano1979/ITC/main/example_004_movies.json"

df = pd.read_json(json_url)
df.head()
# Out:
#                                   title  year cast    genres  \
# 0            After Dark in Central Park  1900   []        []
# 1  Boarding School Girls' Pajama Parade  1900   []        []
# 2        Buffalo Bill's Wild West Parad  1900   []        []
# 3                                Caught  1900   []        []
# 4                  Clowns Spinning Hats  1900   []  [Silent]
#
#                    href                                            extract  \
# 0                  None                                                NaN
# 1                  None                                                NaN
# 2                  None                                                NaN
# 3                  None                                                NaN
# 4  Clowns_Spinning_Hats  Clowns Spinning Hats is a black-and-white sile...
#
#   thumbnail  thumbnail_width  thumbnail_height
# 0       NaN              NaN               NaN
# 1       NaN              NaN               NaN
# 2       NaN              NaN               NaN
# 3       NaN              NaN               NaN
# 4       NaN              NaN               NaN

# %% [markdown]
# ## 6. Lectura de archivos de Excel (`.xlsx`) desde GitHub
#
# Para leer archivos de Excel almacenados en GitHub, normalmente la URL debe incluir el parámetro `?raw=1` o usar el enlace `raw`.
#
# En este ejemplo se deja una URL de plantilla para que la reemplaces por tu archivo real.

# %%
# Plantilla de URL para un archivo de Excel en GitHub
#excel_url = "https://github.com/usuario/repositorio/raw/rama/ruta/archivo.xlsx"  # ERROR
excel_url = "https://raw.githubusercontent.com/hmedrano1979/ITC/main/Ventas%20(Trabajo%20final).xlsx"


# Lectura de una sola hoja (por defecto la primera)
df_excel = pd.read_excel(excel_url)
df_excel.head()

# Lectura de una hoja específica por nombre  Hoja 1
df_excel_hoja1 = pd.read_excel(excel_url, sheet_name="Cliente")
df_excel_hoja1.head()
# Out:
#   Identificación_Clie   Nombres Apellidos     Genero     Celular Nacionalidad  \
# 0            CLIE1000     Sofía      Díaz    Femnino  3690840711   Colombiano
# 1            CLIE1001    Andrés     López  Masculino  3458297268      Chileno
# 2            CLIE1002     Laura     Pérez    Femnino  3796345771    Argentino
# 3            CLIE1003  Fernando  Martínez  Masculino  3175272825    Argentino
# 4            CLIE1004     María    Torres    Femnino  3355109790      Chileno
#
#   Estado Civil
# 0      Soltero
# 1       Casado
# 2  Unión Libre
# 3  Unión Libre
# 4      Soltero

# %%
# Lectura de una hoja específica por nombre  Hoja 2
df_excel_hoja2 = pd.read_excel(excel_url, sheet_name="Articulo")
df_excel_hoja2.head()
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0        NaN         NaN         NaN         NaN        NaN            NaN
# 1        NaN         NaN         NaN         NaN        NaN            NaN
# 2  CódigoArt         NaN         NaN      Nombre  Proveedor  Precio Compra
# 3     ART100         NaN         NaN  Producto_0     Adidas         420496
# 4     ART101         NaN         NaN  Producto_1     Hasbro          49255
#
#          Unnamed: 6
# 0               NaN
# 1               NaN
# 2         Categoría
# 3  Electrodoméstico
# 4           Muebles

# %%
# Lectura de una hoja específica por nombre  Hoja 3
df_excel_hoja3 = pd.read_excel(excel_url, sheet_name="Vendedor")
df_excel_hoja3.head()
# Out:
#   Identificación_Vend   Nombres  Apellidos     Genero     Celular
# 0             VEND200   Bleider  Hernández  Masculino  3273198382
# 1             VEND201    Martin      Gómez  Masculino  3889697273
# 2             VEND202    Sandra      Gómez   Femenino  3644821826
# 3             VEND203  Yolaider   Martínez   Femenino  3779028607
# 4             VEND204     Pablo      Gómez  Masculino  3490105229

# %%
# Lectura de una hoja específica por nombre  Hoja 4
df_excel_hoja4 = pd.read_excel(excel_url, sheet_name="Factura")
df_excel_hoja4.head()
# Out:
#         Fecha  Todorico #Factura   Cliente Articulo Vendedor  Cantidad  \
# 0  01/02/2023       NaN  FACT563  CLIE1012   ART125  VEND207         3
# 1  02/02/2023       NaN  FACT551  CLIE1035   ART117  VEND201         5
# 2  23/02/2023       NaN  FACT507  CLIE1005   ART115  VEND202         8
# 3  11/03/2023       NaN  FACT543  CLIE1049   ART129  VEND209         1
# 4  16/03/2023       NaN  FACT561  CLIE1033   ART125  VEND209         3
#
#    Precio Venta  SuperGiros
# 0        520000         NaN
# 1        350000         NaN
# 2        300000         NaN
# 3        450000         NaN
# 4        600000         NaN

# %% [markdown]
# ## 7. Lectura de múltiples hojas de Excel como diccionario de DataFrames
#
# Si el archivo de Excel tiene varias hojas que quieres cargar a la vez, puedes usar `sheet_name=None` para obtener un diccionario de DataFrames.

# %%
# Lectura de todas las hojas de un Excel (cuando tengas una URL válida)
all_sheets = pd.read_excel(excel_url, sheet_name=None)

# Recorremos las hojas y mostramos el nombre y las primeras filas
for sheet_name, df_sheet in all_sheets.items():
     print(f"Hoja: {sheet_name}")
     display(df_sheet.head())
     print("-" * 40)
# Out:
# Hoja: Cliente
#   Identificación_Clie   Nombres Apellidos     Genero     Celular Nacionalidad  \
# 0            CLIE1000     Sofía      Díaz    Femnino  3690840711   Colombiano
# 1            CLIE1001    Andrés     López  Masculino  3458297268      Chileno
# 2            CLIE1002     Laura     Pérez    Femnino  3796345771    Argentino
# 3            CLIE1003  Fernando  Martínez  Masculino  3175272825    Argentino
# 4            CLIE1004     María    Torres    Femnino  3355109790      Chileno
#
#   Estado Civil
# 0      Soltero
# 1       Casado
# 2  Unión Libre
# 3  Unión Libre
# 4      Soltero
# ----------------------------------------
# Hoja: Articulo
#   Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0        NaN         NaN         NaN         NaN        NaN            NaN
# 1        NaN         NaN         NaN         NaN        NaN            NaN
# 2  CódigoArt         NaN         NaN      Nombre  Proveedor  Precio Compra
# 3     ART100         NaN         NaN  Producto_0     Adidas         420496
# 4     ART101         NaN         NaN  Producto_1     Hasbro          49255
#
#          Unnamed: 6
# 0               NaN
# 1               NaN
# 2         Categoría
# 3  Electrodoméstico
# 4           Muebles
# ----------------------------------------
# Hoja: Vendedor
#   Identificación_Vend   Nombres  Apellidos     Genero     Celular
# 0             VEND200   Bleider  Hernández  Masculino  3273198382
# 1             VEND201    Martin      Gómez  Masculino  3889697273
# 2             VEND202    Sandra      Gómez   Femenino  3644821826
# 3             VEND203  Yolaider   Martínez   Femenino  3779028607
# 4             VEND204     Pablo      Gómez  Masculino  3490105229
# ----------------------------------------
# Hoja: Factura
#         Fecha  Todorico #Factura   Cliente Articulo Vendedor  Cantidad  \
# 0  01/02/2023       NaN  FACT563  CLIE1012   ART125  VEND207         3
# 1  02/02/2023       NaN  FACT551  CLIE1035   ART117  VEND201         5
# 2  23/02/2023       NaN  FACT507  CLIE1005   ART115  VEND202         8
# 3  11/03/2023       NaN  FACT543  CLIE1049   ART129  VEND209         1
# 4  16/03/2023       NaN  FACT561  CLIE1033   ART125  VEND209         3
#
#    Precio Venta  SuperGiros
# 0        520000         NaN
# 1        350000         NaN
# 2        300000         NaN
# 3        450000         NaN
# 4        600000         NaN
# ----------------------------------------

# %% [markdown]
# ## 8. Lectura de archivos Parquet desde GitHub
#
# Los archivos Parquet son muy usados en entornos de Big Data por su compresión y eficiencia.
#
# Para leer Parquet con `pandas`, se recomienda tener instaladas las librerías `pyarrow` o `fastparquet`. La lectura desde GitHub funciona igual que con otros formatos, usando la URL `raw`.
#
# Ten en cuenta que, según el entorno donde ejecutes el notebook, puede que necesites instalar dependencias adicionales.

# %%
# Plantilla de URL para un archivo Parquet en GitHub
#parquet_url = "https://github.com/hmedrano1979/ITC/blob/main/fichero_lab_unir.parquet"  # ERROR
parquet_url = "https://github.com/hmedrano1979/ITC/blob/main/fichero_lab_unir.parquet?raw=1"
df_parquet = pd.read_parquet(parquet_url)
df_parquet.head()
# Out:
#    Unnamed: 0 num_expediente       fecha      hora  \
# 0           0    2021S000047  01/01/2021  11:38:00
# 1           1    2021S000142  04/01/2021  11:30:00
# 2           2    2021S000142  04/01/2021  11:30:00
# 3           3    2021S000142  04/01/2021  11:30:00
# 4           4    2021S000142  04/01/2021  11:30:00
#
#                                         localizacion  ... coordenada_y_utm  \
# 0  CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...  ...    4.473.586.644
# 1   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  ...    4.476.216.426
# 2   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  ...    4.476.216.426
# 3   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  ...    4.476.216.426
# 4   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  ...    4.476.216.426
#
#    positiva_alcohol positiva_droga tipo_vehiculo lesividad
# 0                 N            NaN          None      None
# 1                 N            NaN          None      None
# 2                 N            NaN          None      None
# 3                 N            NaN          None      None
# 4                 N            NaN          None      None
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 9. Resumen
#
# En este notebook has visto cómo:
#
# - Importar `pandas` y configurar opciones básicas de visualización.
# - Obtener y usar la URL `raw` de archivos en GitHub.
# - Leer archivos CSV, TXT, JSON, Excel y Parquet directamente desde GitHub.
#
# Para adaptar este notebook a tu proyecto:
# 1. Sube tus archivos al repositorio de GitHub.
# 2. Obtén el enlace `raw` de cada archivo.
# 3. Reemplaza las URL de ejemplo por las tuyas.
# 4. Ajusta parámetros adicionales (delimitador, nombre de hoja, etc.) según el formato de tus datos.
#
# De esta forma tendrás una **plantilla reutilizable** para leer datos desde GitHub en distintos formatos.
